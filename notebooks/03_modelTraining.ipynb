# %% [markdown]
# # 03 Model Training
# This notebook trains multiple regression models and saves the best ones.

# %%
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
import joblib

# Training logic here...
