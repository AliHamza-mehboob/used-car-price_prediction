# %% [markdown]
# # 02 Data Preprocessing
# This notebook handles feature engineering and data transformation.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

df = pd.read_csv('../data/train.csv')
# Encoding and Scaling logic here...
